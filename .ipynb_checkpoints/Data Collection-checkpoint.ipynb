# %% [markdown]
# # Scraping Websites for Data and Cleaning
# So one of my interests is korean pop music (currently taking the world by storm), and I think there are some interesting trend that can be observed so the following are some simple visualization of kpop data. This involves some new concepts I have never tried before in terms of acquiring data. This notebook will include my scraping of data from the gaon charts.

# %%
import seaborn as sns
import pandas as pd
import re
import os

# %%
## need to scrape data from: gaon, spotify, 
import requests
url = "http://www.gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL"
page = requests.get(url)

# %%
import bs4
soup = bs4.BeautifulSoup(page.content, 'lxml')
table = soup.find(name='table')
#table

# %%
result = pd.DataFrame([[td.text for td in row.findAll('td')] for row in table.findChildren('tr')])
#print(table.findChildren(['tr']))
result.head()
# Out:
#       0     1     2                                                3  \
# 0  None  None  None                                             None
# 1     1     -             \n그대라는 시\n태연 (TAEYEON)|호텔 델루나 OST Part.3\n
# 2     2   new        \n내 맘을 볼 수 있나요\n헤이즈 (Heize)|호텔 델루나 OST Part.5\n
# 3     3     1                            \n술이 문제야\n장혜진, 윤민수|술이 문제야\n
# 4     4     -                                     \n니 소식\n송하예|니 소식\n
#
#                 4                                                 5  \
# 0            None                                              None
# 1  \n44,367,923\n                               \n냠냠엔터테인먼트\n카카오 M\n
# 2  \n36,229,004\n                               \n냠냠엔터테인먼트\n카카오 M\n
# 3  \n35,722,651\n  \n젤리피쉬 엔터테인먼트\n지니뮤직, Stone Music Entertainment\n
# 4  \n32,875,130\n                                 \n더하기미디어\n카카오 M\n
#
#                   6                                         7
# 0              None                                      None
# 1  트위터\n페이스북\n웨이브\n  \nPLAY\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n
# 2  트위터\n페이스북\n웨이브\n  \nPLAY\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n
# 3  트위터\n페이스북\n웨이브\n  \nPLAY\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n
# 4  트위터\n페이스북\n웨이브\n  \nPLAY\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n

# %%
pt = r'\W+'
col_names = [re.sub(pt, '', th.string) for th in table.find('tr')]
result = result.drop([1,2,6,7], axis=1)

# %%
col_names
# Out:
# ['', 'Ranking', 'TitleArtist', '가온지수', 'Production', 'Share', 'Play']

# %%
col_dict = dict(zip(result.columns, col_names[1:5]))
result = result.rename(columns=col_dict)
result = result.drop(0)

# %%
# clean text within the table 
cleaned_result = result.apply(lambda x: x.apply(lambda y: re.sub(r'\n', ' ', y)))
alter = result['TitleArtist'].apply(lambda x: re.sub(r'\n', 'newline ', x))

cleaned_result['Album'] = result['TitleArtist'].apply(lambda x: re.search(r'\|(.*)$', x)[1])
cleaned_result['Artist'] = result['TitleArtist'].apply(lambda x: re.search(r'(.*)\|', x)[1])
cleaned_result['Title'] = alter.apply(lambda x: re.search(r'(?<=newline).*?(?=newline)', x)[0])
cleaned_result['Week'] = 31
cleaned_result['Year'] = 2019
cleaned_result.head()
# Out:
#   Ranking                                   TitleArtist          가온지수  \
# 1       1        그대라는 시 태연 (TAEYEON)|호텔 델루나 OST Part.3    44,367,923
# 2       2   내 맘을 볼 수 있나요 헤이즈 (Heize)|호텔 델루나 OST Part.5    36,229,004
# 3       3                       술이 문제야 장혜진, 윤민수|술이 문제야    35,722,651
# 4       4                                니 소식 송하예|니 소식    32,875,130
# 5       5                  헤어져줘서 고마워 벤 (Ben)|헤어져줘서 고마워    32,816,876
#
#                                       Production              Album  \
# 1                                냠냠엔터테인먼트 카카오 M   호텔 델루나 OST Part.3
# 2                                냠냠엔터테인먼트 카카오 M   호텔 델루나 OST Part.5
# 3   젤리피쉬 엔터테인먼트 지니뮤직, Stone Music Entertainment              술이 문제야
# 4                                  더하기미디어 카카오 M                니 소식
# 5                                    메이저나인 지니뮤직           헤어져줘서 고마워
#
#          Artist          Title  Week  Year
# 1  태연 (TAEYEON)         그대라는 시    31  2019
# 2   헤이즈 (Heize)   내 맘을 볼 수 있나요    31  2019
# 3      장혜진, 윤민수         술이 문제야    31  2019
# 4           송하예           니 소식    31  2019
# 5       벤 (Ben)      헤어져줘서 고마워    31  2019

# %%
# @source a web scraping article I found on Towards Data Science
# https://towardsdatascience.com/a-short-practical-how-to-guide-to-scrape-data-from-a-website-using-python-888373227d4f

PATH = os.path.join("Users","catherinegee","Desktop","cs misc","ds-for-fun") # you need to change to your local path
res = pd.DataFrame()

end = '&targetTime=31&hitYear=2019&termGbn=week'
groups = ['&targetTime=', '&hitYear=', '&termGbn=week']

opts = soup.find(name='select', attrs={'id':'chart_week_select'})
lst = []
for c in opts.children:
    lst += [c]
    
num_times = len(lst) - 2
pth = '/Users/catherinegee/Desktop/cs misc/ds-for-fun/table.csv'
cleaned_result.to_csv(pth)

# %%
def clean_df(result, table, week, year):
    """Cleans the table as done in example dataframe"""
    pt = r'\W+'
    col_names = [re.sub(pt, '', th.string) for th in table.find('tr')]
    result = result.drop([1,2,6,7], axis=1)
    col_dict = dict(zip(result.columns, col_names[1:5]))
    result = result.rename(columns=col_dict)
    result = result.drop(0)
    cleaned_result = result.apply(lambda x: x.apply(lambda y: re.sub(r'\n', ' ', y)))
    alter = result['TitleArtist'].apply(lambda x: re.sub(r'\n', 'newline ', x))

    cleaned_result['Album'] = result['TitleArtist'].apply(lambda x: re.search(r'\|(.*)$', x)[1])
    cleaned_result['Artist'] = result['TitleArtist'].apply(lambda x: re.search(r'(.*)\|', x)[1])
    cleaned_result['Title'] = alter.apply(lambda x: re.search(r'(?<=newline).*?(?=newline)', x)[0])
    cleaned_result['Week'] = week
    cleaned_result['Year'] = year
    return cleaned_result
    
def table_to_df(t, week, year): 
    """Turns the table into a datafram using pandas"""
    result = pd.DataFrame([[td.text for td in row.findAll('td')] for row in t.findChildren('tr')])
    return clean_df(result, t, week, year)

def update_date(week, year):
    """Updates the date by week number and year"""
    year = int(year)
    week = int(week) - 1
    if week == 0:
        year -= 1
        week = 52
    elif week < 10:
        week = '0' + str(week)
    #year = str(year)
    return int(week), year, groups[0] + str(week) + groups[1] + str(year) + groups[2]

for i in range(num_times):
    #print(i)
    week_n = re.search(r'(?<=&targetTime=).*?(?=&hitYear=)', end)[0] 
    year = re.search(r'(?<=&hitYear=).*?(?=&termGbn=week)', end)[0] 
    w, y, end = update_date(week_n, year)
    print(w,y,end)
    url_week = url + end
    pg = requests.get(url_week)
    sp = bs4.BeautifulSoup(pg.content, 'lxml')
    table = sp.find(name='table')
    df1 = table_to_df(table, w, y)
    res = res.append(df1)
    if i % 100 == 0 or i == 1002:
        res.to_csv(pth)
# Out:
# 30 2019 &targetTime=30&hitYear=2019&termGbn=week
# 29 2019 &targetTime=29&hitYear=2019&termGbn=week
# 28 2019 &targetTime=28&hitYear=2019&termGbn=week
# 27 2019 &targetTime=27&hitYear=2019&termGbn=week
# 26 2019 &targetTime=26&hitYear=2019&termGbn=week
# 25 2019 &targetTime=25&hitYear=2019&termGbn=week
# 24 2019 &targetTime=24&hitYear=2019&termGbn=week
# 23 2019 &targetTime=23&hitYear=2019&termGbn=week
# 22 2019 &targetTime=22&hitYear=2019&termGbn=week
# 21 2019 &targetTime=21&hitYear=2019&termGbn=week
# 20 2019 &targetTime=20&hitYear=2019&termGbn=week
# 19 2019 &targetTime=19&hitYear=2019&termGbn=week
# 18 2019 &targetTime=18&hitYear=2019&termGbn=week
# 17 2019 &targetTime=17&hitYear=2019&termGbn=week
# 16 2019 &targetTime=16&hitYear=2019&termGbn=week
# 15 2019 &targetTime=15&hitYear=2019&termGbn=week
# 14 2019 &targetTime=14&hitYear=2019&termGbn=week
# 13 2019 &targetTime=13&hitYear=2019&termGbn=week
# 12 2019 &targetTime=12&hitYear=2019&termGbn=week
# 11 2019 &targetTime=11&hitYear=2019&termGbn=week
# 10 2019 &targetTime=10&hitYear=2019&termGbn=week
# 9 2019 &targetTime=09&hitYear=2019&termGbn=week
# 8 2019 &targetTime=08&hitYear=2019&termGbn=week
# 7 2019 &targetTime=07&hitYear=2019&termGbn=week
# 6 2019 &targetTime=06&hitYear=2019&termGbn=week
# 5 2019 &targetTime=05&hitYear=2019&termGbn=week
# 4 2019 &targetTime=04&hitYear=2019&termGbn=week
# 3 2019 &targetTime=03&hitYear=2019&termGbn=week
# 2 2019 &targetTime=02&hitYear=2019&termGbn=week
# 1 2019 &targetTime=01&hitYear=2019&termGbn=week
# 52 2018 &targetTime=52&hitYear=2018&termGbn=week
# 51 2018 &targetTime=51&hitYear=2018&termGbn=week
# 50 2018 &targetTime=50&hitYear=2018&termGbn=week
# 49 2018 &targetTime=49&hitYear=2018&termGbn=week
# 48 2018 &targetTime=48&hitYear=2018&termGbn=week
# 47 2018 &targetTime=47&hitYear=2018&termGbn=week
# 46 2018 &targetTime=46&hitYear=2018&termGbn=week
# 45 2018 &targetTime=45&hitYear=2018&termGbn=week
# 44 2018 &targetTime=44&hitYear=2018&termGbn=week
# 43 2018 &targetTime=43&hitYear=2018&termGbn=week
# 42 2018 &targetTime=42&hitYear=2018&termGbn=week
# 41 2018 &targetTime=41&hitYear=2018&termGbn=week
# 40 2018 &targetTime=40&hitYear=2018&termGbn=week
# 39 2018 &targetTime=39&hitYear=2018&termGbn=week
# 38 2018 &targetTime=38&hitYear=2018&termGbn=week
# 37 2018 &targetTime=37&hitYear=2018&termGbn=week
# 36 2018 &targetTime=36&hitYear=2018&termGbn=week
# 35 2018 &targetTime=35&hitYear=2018&termGbn=week
# 34 2018 &targetTime=34&hitYear=2018&termGbn=week
# 33 2018 &targetTime=33&hitYear=2018&termGbn=week
# 32 2018 &targetTime=32&hitYear=2018&termGbn=week
# 31 2018 &targetTime=31&hitYear=2018&termGbn=week
# 30 2018 &targetTime=30&hitYear=2018&termGbn=week
# 29 2018 &targetTime=29&hitYear=2018&termGbn=week
# 28 2018 &targetTime=28&hitYear=2018&termGbn=week
# 27 2018 &targetTime=27&hitYear=2018&termGbn=week
# 26 2018 &targetTime=26&hitYear=2018&termGbn=week
# 25 2018 &targetTime=25&hitYear=2018&termGbn=week
# 24 2018 &targetTime=24&hitYear=2018&termGbn=week
# 23 2018 &targetTime=23&hitYear=2018&termGbn=week
# 22 2018 &targetTime=22&hitYear=2018&termGbn=week
# 21 2018 &targetTime=21&hitYear=2018&termGbn=week
# 20 2018 &targetTime=20&hitYear=2018&termGbn=week
# 19 2018 &targetTime=19&hitYear=2018&termGbn=week
# 18 2018 &targetTime=18&hitYear=2018&termGbn=week
# 17 2018 &targetTime=17&hitYear=2018&termGbn=week
# 16 2018 &targetTime=16&hitYear=2018&termGbn=week
# 15 2018 &targetTime=15&hitYear=2018&termGbn=week
# 14 2018 &targetTime=14&hitYear=2018&termGbn=week
# 13 2018 &targetTime=13&hitYear=2018&termGbn=week
# 12 2018 &targetTime=12&hitYear=2018&termGbn=week
# 11 2018 &targetTime=11&hitYear=2018&termGbn=week
# 10 2018 &targetTime=10&hitYear=2018&termGbn=week
# 9 2018 &targetTime=09&hitYear=2018&termGbn=week
# 8 2018 &targetTime=08&hitYear=2018&termGbn=week
# 7 2018 &targetTime=07&hitYear=2018&termGbn=week
# 6 2018 &targetTime=06&hitYear=2018&termGbn=week
# 5 2018 &targetTime=05&hitYear=2018&termGbn=week
# 4 2018 &targetTime=04&hitYear=2018&termGbn=week
# 3 2018 &targetTime=03&hitYear=2018&termGbn=week
# 2 2018 &targetTime=02&hitYear=2018&termGbn=week
# 1 2018 &targetTime=01&hitYear=2018&termGbn=week
# 52 2017 &targetTime=52&hitYear=2017&termGbn=week
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-083ca8dc57b5> in <module>()
#      44     sp = bs4.BeautifulSoup(pg.content, 'lxml')
#      45     table = sp.find(name='table')
# ---> 46     df1 = table_to_df(table, w, y)
#      47     res = res.append(df1)
#      48     if i % 100 == 0 or i == 1002:
#
# <ipython-input-10-083ca8dc57b5> in table_to_df(t, week, year)
#      20     """Turns the table into a datafram using pandas"""
#      21     result = pd.DataFrame([[td.text for td in row.findAll('td')] for row in t.findChildren('tr')])
# ---> 22     return clean_df(result, t, week, year)
#      23
#      24 def update_date(week, year):
#
# <ipython-input-10-083ca8dc57b5> in clean_df(result, table, week, year)
#       3     pt = r'\W+'
#       4     col_names = [re.sub(pt, '', th.string) for th in table.find('tr')]
# ----> 5     result = result.drop([1,2,6,7], axis=1)
#       6     col_dict = dict(zip(result.columns, col_names[1:5]))
#       7     result = result.rename(columns=col_dict)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3742             if errors != 'ignore':
#    3743                 raise ValueError('labels %s not contained in axis' %
# -> 3744                                  labels[mask])
#    3745             indexer = indexer[~mask]
#    3746         return self.delete(indexer)
#
# ValueError: labels [7] not contained in axis
