# %% [markdown]
# # The Data of Kpop
# The age old question of many fans (of kpop or otherwise) is which artist is the best? Generally this is answered by affirmation, but I am taking it to the charts to determine this. In this juypter notebook I'm going to explore the Gaon Digital Weekly charts from the weeks of 08/03/2019 to 12/27/2009 so that we may arrive at some sort of conclusion. Who really is the best and what can be reflective of the Korean culture itself? Eventually I would like to expand this project to include more data, but my skills are admittedly lacking at this point of time. See the end of the notebook for some future notes!

# %%
import pandas as pd

# %%
tbl = pd.read_csv('table.csv')
len(tbl)
# Out:
# 200600

# %%
tbl.columns
# Out:
# Index(['Unnamed: 0', 'Ranking', 'TitleArtist', '가온지수', 'Production', 'Album',
#        'Artist', 'Title', 'Week', 'Year'],
#       dtype='object')

# %%
tbl.head()
# Out:
#    Unnamed: 0  Ranking                              TitleArtist          가온지수  \
# 0           1        1   그대라는 시 태연 (TAEYEON)|호텔 델루나 OST Part.3    54,157,121
# 1           2        2                  술이 문제야 장혜진, 윤민수|술이 문제야    38,344,212
# 2           3        3             헤어져줘서 고마워 벤 (Ben)|헤어져줘서 고마워    37,501,138
# 3           4        4                           니 소식 송하예|니 소식    34,636,177
# 4           5        5                   인사 멜로망스(MeloMance)|인사    29,601,177
#
#                                       Production              Album  \
# 0                                냠냠엔터테인먼트 카카오 M   호텔 델루나 OST Part.3
# 1   젤리피쉬 엔터테인먼트 지니뮤직, Stone Music Entertainment              술이 문제야
# 2                                    메이저나인 지니뮤직           헤어져줘서 고마워
# 3                                  더하기미디어 카카오 M                니 소식
# 4                              민트페이퍼, 광합성 카카오 M                  인사
#
#             Artist       Title  Week  Year
# 0     태연 (TAEYEON)      그대라는 시    30  2019
# 1         장혜진, 윤민수      술이 문제야    30  2019
# 2          벤 (Ben)   헤어져줘서 고마워    30  2019
# 3              송하예        니 소식    30  2019
# 4  멜로망스(MeloMance)          인사    30  2019

# %% [markdown]
# ## Top Ranking
# First I'm going to check out the number 1 ranked songs for each week.

# %%
numberOne = tbl[tbl['Ranking'] == 1]
numberOne.head()
# Out:
#      Unnamed: 0  Ranking                              TitleArtist  \
# 0             1        1   그대라는 시 태연 (TAEYEON)|호텔 델루나 OST Part.3
# 200           1        1             헤어져줘서 고마워 벤 (Ben)|헤어져줘서 고마워
# 400           1        1             헤어져줘서 고마워 벤 (Ben)|헤어져줘서 고마워
# 600           1        1                  술이 문제야 장혜진, 윤민수|술이 문제야
# 800           1        1                  술이 문제야 장혜진, 윤민수|술이 문제야
#
#              가온지수                                     Production  \
# 0     54,157,121                                 냠냠엔터테인먼트 카카오 M
# 200   44,070,073                                     메이저나인 지니뮤직
# 400   50,307,557                                     메이저나인 지니뮤직
# 600   56,689,740    젤리피쉬 엔터테인먼트 지니뮤직, Stone Music Entertainment
# 800   56,207,990    젤리피쉬 엔터테인먼트 지니뮤직, Stone Music Entertainment
#
#                  Album        Artist       Title  Week  Year
# 0    호텔 델루나 OST Part.3  태연 (TAEYEON)      그대라는 시    30  2019
# 200          헤어져줘서 고마워       벤 (Ben)   헤어져줘서 고마워    29  2019
# 400          헤어져줘서 고마워       벤 (Ben)   헤어져줘서 고마워    28  2019
# 600             술이 문제야      장혜진, 윤민수      술이 문제야    27  2019
# 800             술이 문제야      장혜진, 윤민수      술이 문제야    26  2019

# %% [markdown]
# ### This is a pretty quick way to see who is the "best", by examining who has held rank 1 the longest.

# %%
#numberOneSong = numberOne.groupby('Title').agg(sum)
#numberOneArtist = ...
#numberOneSong
numberOne
# Out:
#         Unnamed: 0  Ranking  \
# 0                1        1
# 200              1        1
# 400              1        1
# 600              1        1
# 800              1        1
# 1000             1        1
# 1200             1        1
# 1400             1        1
# 1600             1        1
# 1800             1        1
# 2000             1        1
# 2200             1        1
# 2400             1        1
# 2600             1        1
# 2800             1        1
# 3000             1        1
# 3200             1        1
# 3400             1        1
# 3600             1        1
# 3800             1        1
# 4000             1        1
# 4200             1        1
# 4400             1        1
# 4600             1        1
# 4800             1        1
# 5000             1        1
# 5200             1        1
# 5400             1        1
# 5600             1        1
# 5800             1        1
# ...            ...      ...
# 194600           1        1
# 194800           1        1
# 195000           1        1
# 195200           1        1
# 195400           1        1
# 195600           1        1
# 195800           1        1
# 196000           1        1
# 196200           1        1
# 196400           1        1
# 196600           1        1
# 196800           1        1
# 197000           1        1
# 197200           1        1
# 197400           1        1
# 197600           1        1
# 197800           1        1
# 198000           1        1
# 198200           1        1
# 198400           1        1
# 198600           1        1
# 198800           1        1
# 199000           1        1
# 199200           1        1
# 199400           1        1
# 199600           1        1
# 199800           1        1
# 200000           1        1
# 200200           1        1
# 200400           1        1
#
#                                               TitleArtist          가온지수  \
# 0                  그대라는 시 태연 (TAEYEON)|호텔 델루나 OST Part.3    54,157,121
# 200                          헤어져줘서 고마워 벤 (Ben)|헤어져줘서 고마워    44,070,073
# 400                          헤어져줘서 고마워 벤 (Ben)|헤어져줘서 고마워    50,307,557
# 600                               술이 문제야 장혜진, 윤민수|술이 문제야    56,689,740
# 800                               술이 문제야 장혜진, 윤민수|술이 문제야    56,207,990
# 1000                           솔직하게 말해서 나 김나영|솔직하게 말해서 나    38,999,150
# 1200                           솔직하게 말해서 나 김나영|솔직하게 말해서 나    48,230,368
# 1400          사랑에 연습이 있었다면 (Prod. 2soo) 임재현|사랑에 연습이 있었다면    44,009,459
# 1600          사랑에 연습이 있었다면 (Prod. 2soo) 임재현|사랑에 연습이 있었다면    44,930,544
# 1800          사랑에 연습이 있었다면 (Prod. 2soo) 임재현|사랑에 연습이 있었다면    45,959,839
# 2000                                 주저하는 연인들을 위해 잔나비|전설    43,016,843
# 2200                                 Goodbye 박효신|Goodbye    47,435,952
# 2400     작은 것들을 위한 시 (Boy With Luv) (Feat. Hals... 방탄소...   46,643,572
# 2600     작은 것들을 위한 시 (Boy With Luv) (Feat. Hals... 방탄소...   51,568,428
# 2800     작은 것들을 위한 시 (Boy With Luv) (Feat. Hals... 방탄소...   64,837,014
# 3000                              나만, 봄 볼빨간사춘기|사춘기집Ⅰ 꽃기운    66,798,264
# 3200     사계 (Four Seasons) 태연 (TAEYEON)|사계 (Four Seaso...   60,603,160
# 3400     사계 (Four Seasons) 태연 (TAEYEON)|사계 (Four Seaso...   69,891,643
# 3600           그건 아마 우리의 잘못은 아닐 거야 백예린|Our love is great    53,753,794
# 3800     술이 달다 (Feat. 크러쉬) 에픽하이 (EPIK HIGH)|sleepless ...   61,851,810
# 4000       옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    53,853,397
# 4200       옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 4400       옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 4600       옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 4800       옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 5000       옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 5200       옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 5400       옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 5600       옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 5800       옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# ...                                                   ...           ...
# 194600     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 194800     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 195000     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 195200     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 195400     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 195600     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 195800     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 196000     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 196200     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 196400     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 196600     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 196800     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 197000     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 197200     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 197400     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 197600     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 197800     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 198000     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 198200     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 198400     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 198600     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 198800     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 199000     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 199200     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 199400     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 199600     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 199800     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 200000     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 200200     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
# 200400     옥탑방 엔플라잉 (N.Flying)|FLY HIGH PROJECT #2 `옥탑방`    56,101,865
#
#                                            Production  \
# 0                                     냠냠엔터테인먼트 카카오 M
# 200                                       메이저나인 지니뮤직
# 400                                       메이저나인 지니뮤직
# 600      젤리피쉬 엔터테인먼트 지니뮤직, Stone Music Entertainment
# 800      젤리피쉬 엔터테인먼트 지니뮤직, Stone Music Entertainment
# 1000                                네버랜드엔터테인먼트 카카오 M
# 1200                                네버랜드엔터테인먼트 카카오 M
# 1400                            엔에스씨컴퍼니, 디원미디어 카카오 M
# 1600                            엔에스씨컴퍼니, 디원미디어 카카오 M
# 1800                            엔에스씨컴퍼니, 디원미디어 카카오 M
# 2000                                    페포니 뮤직 카카오 M
# 2200                                 글러브엔터테인먼트 카카오 M
# 2400                              빅히트 엔터테인먼트 Dreamus
# 2600                              빅히트 엔터테인먼트 Dreamus
# 2800                              빅히트 엔터테인먼트 Dreamus
# 3000                                     쇼파르뮤직 카카오 M
# 3200                        SM Entertainment Dreamus
# 3400                        SM Entertainment Dreamus
# 3600                       JYP Entertainment Dreamus
# 3800                                  OURS Co. 카카오 M
# 4000                                 FNC엔터테인먼트 카카오 M
# 4200                                 FNC엔터테인먼트 카카오 M
# 4400                                 FNC엔터테인먼트 카카오 M
# 4600                                 FNC엔터테인먼트 카카오 M
# 4800                                 FNC엔터테인먼트 카카오 M
# 5000                                 FNC엔터테인먼트 카카오 M
# 5200                                 FNC엔터테인먼트 카카오 M
# 5400                                 FNC엔터테인먼트 카카오 M
# 5600                                 FNC엔터테인먼트 카카오 M
# 5800                                 FNC엔터테인먼트 카카오 M
# ...                                               ...
# 194600                               FNC엔터테인먼트 카카오 M
# 194800                               FNC엔터테인먼트 카카오 M
# 195000                               FNC엔터테인먼트 카카오 M
# 195200                               FNC엔터테인먼트 카카오 M
# 195400                               FNC엔터테인먼트 카카오 M
# 195600                               FNC엔터테인먼트 카카오 M
# 195800                               FNC엔터테인먼트 카카오 M
# 196000                               FNC엔터테인먼트 카카오 M
# 196200                               FNC엔터테인먼트 카카오 M
# 196400                               FNC엔터테인먼트 카카오 M
# 196600                               FNC엔터테인먼트 카카오 M
# 196800                               FNC엔터테인먼트 카카오 M
# 197000                               FNC엔터테인먼트 카카오 M
# 197200                               FNC엔터테인먼트 카카오 M
# 197400                               FNC엔터테인먼트 카카오 M
# 197600                               FNC엔터테인먼트 카카오 M
# 197800                               FNC엔터테인먼트 카카오 M
# 198000                               FNC엔터테인먼트 카카오 M
# 198200                               FNC엔터테인먼트 카카오 M
# 198400                               FNC엔터테인먼트 카카오 M
# 198600                               FNC엔터테인먼트 카카오 M
# 198800                               FNC엔터테인먼트 카카오 M
# 199000                               FNC엔터테인먼트 카카오 M
# 199200                               FNC엔터테인먼트 카카오 M
# 199400                               FNC엔터테인먼트 카카오 M
# 199600                               FNC엔터테인먼트 카카오 M
# 199800                               FNC엔터테인먼트 카카오 M
# 200000                               FNC엔터테인먼트 카카오 M
# 200200                               FNC엔터테인먼트 카카오 M
# 200400                               FNC엔터테인먼트 카카오 M
#
#                             Album            Artist  \
# 0               호텔 델루나 OST Part.3      태연 (TAEYEON)
# 200                     헤어져줘서 고마워           벤 (Ben)
# 400                     헤어져줘서 고마워           벤 (Ben)
# 600                        술이 문제야          장혜진, 윤민수
# 800                        술이 문제야          장혜진, 윤민수
# 1000                   솔직하게 말해서 나               김나영
# 1200                   솔직하게 말해서 나               김나영
# 1400                 사랑에 연습이 있었다면               임재현
# 1600                 사랑에 연습이 있었다면               임재현
# 1800                 사랑에 연습이 있었다면               임재현
# 2000                           전설               잔나비
# 2200                      Goodbye               박효신
# 2400    MAP OF THE SOUL _ PERSONA             방탄소년단
# 2600    MAP OF THE SOUL _ PERSONA             방탄소년단
# 2800    MAP OF THE SOUL _ PERSONA             방탄소년단
# 3000                    사춘기집Ⅰ 꽃기운            볼빨간사춘기
# 3200            사계 (Four Seasons)      태연 (TAEYEON)
# 3400            사계 (Four Seasons)      태연 (TAEYEON)
# 3600            Our love is great               백예린
# 3800      sleepless in __________  에픽하이 (EPIK HIGH)
# 4000    FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 4200    FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 4400    FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 4600    FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 4800    FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 5000    FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 5200    FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 5400    FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 5600    FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 5800    FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# ...                           ...               ...
# 194600  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 194800  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 195000  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 195200  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 195400  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 195600  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 195800  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 196000  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 196200  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 196400  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 196600  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 196800  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 197000  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 197200  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 197400  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 197600  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 197800  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 198000  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 198200  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 198400  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 198600  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 198800  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 199000  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 199200  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 199400  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 199600  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 199800  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 200000  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 200200  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
# 200400  FLY HIGH PROJECT #2 `옥탑방`   엔플라잉 (N.Flying)
#
#                                              Title  Week  Year
# 0                                           그대라는 시    30  2019
# 200                                      헤어져줘서 고마워    29  2019
# 400                                      헤어져줘서 고마워    28  2019
# 600                                         술이 문제야    27  2019
# 800                                         술이 문제야    26  2019
# 1000                                    솔직하게 말해서 나    25  2019
# 1200                                    솔직하게 말해서 나    24  2019
# 1400                     사랑에 연습이 있었다면 (Prod. 2soo)    23  2019
# 1600                     사랑에 연습이 있었다면 (Prod. 2soo)    22  2019
# 1800                     사랑에 연습이 있었다면 (Prod. 2soo)    21  2019
# 2000                                  주저하는 연인들을 위해    20  2019
# 2200                                       Goodbye    19  2019
# 2400     작은 것들을 위한 시 (Boy With Luv) (Feat. Hals...    18  2019
# 2600     작은 것들을 위한 시 (Boy With Luv) (Feat. Hals...    17  2019
# 2800     작은 것들을 위한 시 (Boy With Luv) (Feat. Hals...    16  2019
# 3000                                         나만, 봄    15  2019
# 3200                             사계 (Four Seasons)    14  2019
# 3400                             사계 (Four Seasons)    13  2019
# 3600                           그건 아마 우리의 잘못은 아닐 거야    12  2019
# 3800                             술이 달다 (Feat. 크러쉬)    11  2019
# 4000                                           옥탑방    10  2019
# 4200                                           옥탑방     9  2019
# 4400                                           옥탑방     9  2019
# 4600                                           옥탑방     9  2019
# 4800                                           옥탑방     9  2019
# 5000                                           옥탑방     9  2019
# 5200                                           옥탑방     9  2019
# 5400                                           옥탑방     9  2019
# 5600                                           옥탑방     9  2019
# 5800                                           옥탑방     9  2019
# ...                                            ...   ...   ...
# 194600                                         옥탑방     9  2019
# 194800                                         옥탑방     9  2019
# 195000                                         옥탑방     9  2019
# 195200                                         옥탑방     9  2019
# 195400                                         옥탑방     9  2019
# 195600                                         옥탑방     9  2019
# 195800                                         옥탑방     9  2019
# 196000                                         옥탑방     9  2019
# 196200                                         옥탑방     9  2019
# 196400                                         옥탑방     9  2019
# 196600                                         옥탑방     9  2019
# 196800                                         옥탑방     9  2019
# 197000                                         옥탑방     9  2019
# 197200                                         옥탑방     9  2019
# 197400                                         옥탑방     9  2019
# 197600                                         옥탑방     9  2019
# 197800                                         옥탑방     9  2019
# 198000                                         옥탑방     9  2019
# 198200                                         옥탑방     9  2019
# 198400                                         옥탑방     9  2019
# 198600                                         옥탑방     9  2019
# 198800                                         옥탑방     9  2019
# 199000                                         옥탑방     9  2019
# 199200                                         옥탑방     9  2019
# 199400                                         옥탑방     9  2019
# 199600                                         옥탑방     9  2019
# 199800                                         옥탑방     9  2019
# 200000                                         옥탑방     9  2019
# 200200                                         옥탑방     9  2019
# 200400                                         옥탑방     9  2019
#
# [1003 rows x 10 columns]
