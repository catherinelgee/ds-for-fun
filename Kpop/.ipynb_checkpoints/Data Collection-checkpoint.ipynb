# %% [markdown]
# # Scraping Websites for Data and Cleaning
# So one of my interests is korean pop music (currently taking the world by storm), and I think there are some interesting trend that can be observed so the following are some simple visualization of kpop data. This involves some new concepts I have never tried before in terms of acquiring data. This notebook will include my scraping of data from the gaon charts.

# %%
import seaborn as sns
import pandas as pd
import re
import os

# %%
## need to scrape data from: gaon, spotify, 
import requests
url = "http://www.gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL"
page = requests.get(url)

# %%
import bs4
soup = bs4.BeautifulSoup(page.content, 'lxml')
table = soup.find(name='table')
table
# Out:
# <table>
# <colgroup>
# <col width="60"/>
# <col width="60"/>
# <col width="100"/>
# <col/>
# <col width="140"/>
# <col width="180"/>
# <col width="110"/>
# <col width="70"/>
# </colgroup>
# <tr>
# <th colspan="2">Ranking
# 				</th><th colspan="2">Title / Artist
#
# 				</th><th> 가온지수
#
# 				</th><th>Production
# 				</th><th>Share
# 				</th><th>Play
# 			</th></tr>
# <tr>
# <td class="ranking"><span class="no1">1</span></td>
# <td class="change"><div style="text-align:center;width:36px;"><span>-</span></div></td>
# <!--5위 이하 순위 이미지 안보이게-->
# <td class="albumimg"><img alt="sample" src="http://img.gaonchart.co.kr/uploadDir/albumImg/thumb/E7E7DAA02D174E068C47105E122DDA66.jpg"/></td>
# <td class="subject">
# <p title="그대라는 시">그대라는 시</p>
# <p class="singer" title="태연 (TAEYEON) | 호텔 델루나 OST Part.3">태연 (TAEYEON)<span class="bar">|</span>호텔 델루나 OST Part.3</p>
# </td>
# <!--가온지수-->
# <td class="count">
# <p>44,367,923</p>
# </td>
# <td class="production">
# <p class="pro" title="냠냠엔터테인먼트">냠냠엔터테인먼트</p>
# <p class="dist" title="카카오 M">카카오 M</p>
# </td>
# <td class="share"><a class="twitter" href="#" onclick="tweet('@gaonchart_twt [태연 (TAEYEON)-그대라는 시] 2019년 31주 가온디지털차트 1위!!')">트위터</a>
# <a class="facebook" href="#" onclick="facebook('관심 있는 곡의 순위가 궁금하시다면 클릭!! GAON DIGITAL CHART', 'http://img.gaonchart.co.kr/uploadDir/albumImg/thumb/E7E7DAA02D174E068C47105E122DDA66.jpg', '2019년 가온디지털차트 1위곡!! \'태연 (TAEYEON)\'가 부릅니다~~\'그대라는 시\'')">페이스북</a>
# <a class="weibo" href="#" onclick="weibo('관심 있는 곡의 순위가 궁금하시다면 클릭!! GAON DIGITAL CHART', 'http://img.gaonchart.co.kr/uploadDir/albumImg/thumb/E7E7DAA02D174E068C47105E122DDA66.jpg', '2019년 31주차 가온디지털차트 1위곡!! \'태연 (TAEYEON)\'가 부릅니다~~\'그대라는 시\'')">웨이브</a>
# </td>
# <td class="play">
# <div class="chart_play" tabindex="0"><span>PLAY</span>
# <div>
# <ul>
# <li><a href='javascript:go_returnUrl("3715","1807734");' title="새 창으로 열림"><img alt="Melon" src="/images/btn/btn_play_melon.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("1594","1807734");' title="새 창으로 열림"><img alt="Bugs" src="/images/btn/btn_play_bugs.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("2407","1807734");' title="새 창으로 열림"><img alt="genie" src="/images/btn/btn_play_genie.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("1316","1807734");' title="새 창으로 열림"><img alt="mnet" src="/images/btn/btn_play_mnet.gif"/></a></li>
# <!--
# 								<li><a href='javascript:go_returnUrl("5765","1807734");' title="새 창으로 열림"><img src="/images/btn/btn_play_naver.gif" alt="naver" ></a></li>
# 								-->
# <li><a href='javascript:go_returnUrl("2296","1807734");' title="새 창으로 열림"><img alt="soribada" src="/images/btn/btn_play_soribada.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("2407","1807734");' title="새 창으로 열림"><img alt="alleh music" src="/images/btn/btn_play_alleh.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("7829","1807734");' title="새 창으로 열림"><img alt="bainil" src="/images/btn/btn_play_bainil.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("5765","1807734");' title="새 창으로 열림"><img alt="vibe" src="/images/btn/btn_play_vibe.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("8498","1807734");' title="새 창으로 열림"><img alt="vibe" src="/images/btn/btn_play_flo.gif"/></a></li>
# </ul>
# <span></span>
# </div>
# </div>
# </td>
# </tr>
# <tr>
# <td class="ranking"><span class="no2">2</span></td>
# <td class="change"><div style="text-align:center;width:36px;"><span class="new">new</span></div></td>
# <!--5위 이하 순위 이미지 안보이게-->
# <td class="albumimg"><img alt="sample" src="http://img.gaonchart.co.kr/uploadDir/albumImg/thumb/FC49CA094282454D8F41A43E054A66B7.jpg"/></td>
# <td class="subject">
# <p title="내 맘을 볼 수 있나요">내 맘을 볼 수 있나요</p>
# <p class="singer" title="헤이즈 (Heize) | 호텔 델루나 OST Part.5">헤이즈 (Heize)<span class="bar">|</span>호텔 델루나 OST Part.5</p>
# </td>
# <!--가온지수-->
# <td class="count">
# <p>36,229,004</p>
# </td>
# <td class="production">
# <p class="pro" title="냠냠엔터테인먼트">냠냠엔터테인먼트</p>
# <p class="dist" title="카카오 M">카카오 M</p>
# </td>
# <td class="share"><a class="twitter" href="#" onclick="tweet('@gaonchart_twt [헤이즈 (Heize)-내 맘을 볼 수 있나요] 2019년 31주 가온디지털차트 2위!!')">트위터</a>
# <a class="facebook" href="#" onclick="facebook('관심 있는 곡의 순위가 궁금하시다면 클릭!! GAON DIGITAL CHART', 'http://img.gaonchart.co.kr/uploadDir/albumImg/thumb/FC49CA094282454D8F41A43E054A66B7.jpg', '2019년 가온디지털차트 2위곡!! \'헤이즈 (Heize)\'가 부릅니다~~\'내 맘을 볼 수 있나요\'')">페이스북</a>
# <a class="weibo" href="#" onclick="weibo('관심 있는 곡의 순위가 궁금하시다면 클릭!! GAON DIGITAL CHART', 'http://img.gaonchart.co.kr/uploadDir/albumImg/thumb/FC49CA094282454D8F41A43E054A66B7.jpg', '2019년 31주차 가온디지털차트 2위곡!! \'헤이즈 (Heize)\'가 부릅니다~~\'내 맘을 볼 수 있나요\'')">웨이브</a>
# </td>
# <td class="play">
# <div class="chart_play" tabindex="0"><span>PLAY</span>
# <div>
# <ul>
# <li><a href='javascript:go_returnUrl("3715","1813369");' title="새 창으로 열림"><img alt="Melon" src="/images/btn/btn_play_melon.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("1594","1813369");' title="새 창으로 열림"><img alt="Bugs" src="/images/btn/btn_play_bugs.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("2407","1813369");' title="새 창으로 열림"><img alt="genie" src="/images/btn/btn_play_genie.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("1316","1813369");' title="새 창으로 열림"><img alt="mnet" src="/images/btn/btn_play_mnet.gif"/></a></li>
# <!--
# 								<li><a href='javascript:go_returnUrl("5765","1813369");' title="새 창으로 열림"><img src="/images/btn/btn_play_naver.gif" alt="naver" ></a></li>
# 								-->
# <li><a href='javascript:go_returnUrl("2296","1813369");' title="새 창으로 열림"><img alt="soribada" src="/images/btn/btn_play_soribada.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("2407","1813369");' title="새 창으로 열림"><img alt="alleh music" src="/images/btn/btn_play_alleh.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("7829","1813369");' title="새 창으로 열림"><img alt="bainil" src="/images/btn/btn_play_bainil.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("5765","1813369");' title="새 창으로 열림"><img alt="vibe" src="/images/btn/btn_play_vibe.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("8498","1813369");' title="새 창으로 열림"><img alt="vibe" src="/images/btn/btn_play_flo.gif"/></a></li>
# </ul>
# <span></span>
# </div>
# </div>
# </td>
# </tr>
# <tr>
# <td class="ranking"><span class="no3">3</span></td>
# <td class="change"><div style="text-align:center;width:36px;"><span class="down">1</span></div></td>
# <!--5위 이하 순위 이미지 안보이게-->
# <td class="albumimg"><img alt="sample" src="http://img.gaonchart.co.kr/uploadDir/albumImg/thumb/
'')">페이스북</a>
# <a class="weibo" href="#" onclick="weibo('관심 있는 곡의 순위가 궁금하시다면 클릭!! GAON DIGITAL CHART', 'http://img.gaonchart.co.kr/uploadDir/albumImg/thumb/843E6B41A7164778AE08B19AFD7476BA.png', '2019년 31주차 가온디지털차트 198위곡!! \'iKON\'가 부릅니다~~\'사랑을 했다 (LOVE SCENARIO)\'')">웨이브</a>
# </td>
# <td class="play">
# <div class="chart_play" tabindex="0"><span>PLAY</span>
# <div>
# <ul>
# <li><a href='javascript:go_returnUrl("3715","1436717");' title="새 창으로 열림"><img alt="Melon" src="/images/btn/btn_play_melon.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("1594","1436717");' title="새 창으로 열림"><img alt="Bugs" src="/images/btn/btn_play_bugs.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("2407","1436717");' title="새 창으로 열림"><img alt="genie" src="/images/btn/btn_play_genie.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("1316","1436717");' title="새 창으로 열림"><img alt="mnet" src="/images/btn/btn_play_mnet.gif"/></a></li>
# <!--
# 								<li><a href='javascript:go_returnUrl("5765","1436717");' title="새 창으로 열림"><img src="/images/btn/btn_play_naver.gif" alt="naver" ></a></li>
# 								-->
# <li><a href='javascript:go_returnUrl("2296","1436717");' title="새 창으로 열림"><img alt="soribada" src="/images/btn/btn_play_soribada.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("2407","1436717");' title="새 창으로 열림"><img alt="alleh music" src="/images/btn/btn_play_alleh.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("7829","1436717");' title="새 창으로 열림"><img alt="bainil" src="/images/btn/btn_play_bainil.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("5765","1436717");' title="새 창으로 열림"><img alt="vibe" src="/images/btn/btn_play_vibe.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("8498","1436717");' title="새 창으로 열림"><img alt="vibe" src="/images/btn/btn_play_flo.gif"/></a></li>
# </ul>
# <span></span>
# </div>
# </div>
# </td>
# </tr>
# <tr>
# <td class="ranking">199</td>
# <td class="change"><div style="text-align:center;width:36px;"><span class="down">6</span></div></td>
# <!--5위 이하 순위 이미지 안보이게-->
# <td class="albumimg"></td>
# <td class="subject">
# <p title="그리워하다">그리워하다</p>
# <p class="singer" title="비투비 (BTOB) | Brother Act.">비투비 (BTOB)<span class="bar">|</span>Brother Act.</p>
# </td>
# <!--가온지수-->
# <td class="count">
# <p>2,716,427</p>
# </td>
# <td class="production">
# <p class="pro" title="큐브엔터테인먼트">큐브엔터테인먼트</p>
# <p class="dist" title="카카오 M">카카오 M</p>
# </td>
# <td class="share"><a class="twitter" href="#" onclick="tweet('@gaonchart_twt [비투비 (BTOB)-그리워하다] 2019년 31주 가온디지털차트 199위!!')">트위터</a>
# <a class="facebook" href="#" onclick="facebook('관심 있는 곡의 순위가 궁금하시다면 클릭!! GAON DIGITAL CHART', 'http://img.gaonchart.co.kr/uploadDir/albumImg/thumb/A32BCDE8C6AA43BC8FEFDF091F37ED16.png', '2019년 가온디지털차트 199위곡!! \'비투비 (BTOB)\'가 부릅니다~~\'그리워하다\'')">페이스북</a>
# <a class="weibo" href="#" onclick="weibo('관심 있는 곡의 순위가 궁금하시다면 클릭!! GAON DIGITAL CHART', 'http://img.gaonchart.co.kr/uploadDir/albumImg/thumb/A32BCDE8C6AA43BC8FEFDF091F37ED16.png', '2019년 31주차 가온디지털차트 199위곡!! \'비투비 (BTOB)\'가 부릅니다~~\'그리워하다\'')">웨이브</a>
# </td>
# <td class="play">
# <div class="chart_play" tabindex="0"><span>PLAY</span>
# <div>
# <ul>
# <li><a href='javascript:go_returnUrl("3715","1350726");' title="새 창으로 열림"><img alt="Melon" src="/images/btn/btn_play_melon.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("1594","1350726");' title="새 창으로 열림"><img alt="Bugs" src="/images/btn/btn_play_bugs.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("2407","1350726");' title="새 창으로 열림"><img alt="genie" src="/images/btn/btn_play_genie.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("1316","1350726");' title="새 창으로 열림"><img alt="mnet" src="/images/btn/btn_play_mnet.gif"/></a></li>
# <!--
# 								<li><a href='javascript:go_returnUrl("5765","1350726");' title="새 창으로 열림"><img src="/images/btn/btn_play_naver.gif" alt="naver" ></a></li>
# 								-->
# <li><a href='javascript:go_returnUrl("2296","1350726");' title="새 창으로 열림"><img alt="soribada" src="/images/btn/btn_play_soribada.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("2407","1350726");' title="새 창으로 열림"><img alt="alleh music" src="/images/btn/btn_play_alleh.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("7829","1350726");' title="새 창으로 열림"><img alt="bainil" src="/images/btn/btn_play_bainil.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("5765","1350726");' title="새 창으로 열림"><img alt="vibe" src="/images/btn/btn_play_vibe.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("8498","1350726");' title="새 창으로 열림"><img alt="vibe" src="/images/btn/btn_play_flo.gif"/></a></li>
# </ul>
# <span></span>
# </div>
# </div>
# </td>
# </tr>
# <tr>
# <td class="ranking">200</td>
# <td class="change"><div style="text-align:center;width:36px;"><span class="down">48</span></div></td>
# <!--5위 이하 순위 이미지 안보이게-->
# <td class="albumimg"></td>
# <td class="subject">
# <p title="한 페이지가 될 수 있게">한 페이지가 될 수 있게</p>
# <p class="singer" title="DAY6 | The Book of Us _ Gravity">DAY6<span class="bar">|</span>The Book of Us _ Gravity</p>
# </td>
# <!--가온지수-->
# <td class="count">
# <p>2,710,985</p>
# </td>
# <td class="production">
# <p class="pro" title="JYP Entertainment">JYP Entertainment</p>
# <p class="dist" title="Dreamus">Dreamus</p>
# </td>
# <td class="share"><a class="twitter" href="#" onclick="tweet('@gaonchart_twt [DAY6-한 페이지가 될 수 있게] 2019년 31주 가온디지털차트 200위!!')">트위터</a>
# <a class="facebook" href="#" onclick="facebook('관심 있는 곡의 순위가 궁금하시다면 클릭!! GAON DIGITAL CHART', 'http://img.gaonchart.co.kr/uploadDir/albumImg/thumb/F116950A134E492686C79359207B1751.jpg', '2019년 가온디지털차트 200위곡!! \'DAY6\'가 부릅니다~~\'한 페이지가 될 수 있게\'')">페이스북</a>
# <a class="weibo" href="#" onclick="weibo('관심 있는 곡의 순위가 궁금하시다면 클릭!! GAON DIGITAL CHART', 'http://img.gaonchart.co.kr/uploadDir/albumImg/thumb/F116950A134E492686C79359207B1751.jpg', '2019년 31주차 가온디지털차트 200위곡!! \'DAY6\'가 부릅니다~~\'한 페이지가 될 수 있게\'')">웨이브</a>
# </td>
# <td class="play">
# <div class="chart_play" tabindex="0"><span>PLAY</span>
# <div>
# <ul>
# <li><a href='javascript:go_returnUrl("3715","1803631");' title="새 창으로 열림"><img alt="Melon" src="/images/btn/btn_play_melon.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("1594","1803631");' title="새 창으로 열림"><img alt="Bugs" src="/images/btn/btn_play_bugs.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("2407","1803631");' title="새 창으로 열림"><img alt="genie" src="/images/btn/btn_play_genie.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("1316","1803631");' title="새 창으로 열림"><img alt="mnet" src="/images/btn/btn_play_mnet.gif"/></a></li>
# <!--
# 								<li><a href='javascript:go_returnUrl("5765","1803631");' title="새 창으로 열림"><img src="/images/btn/btn_play_naver.gif" alt="naver" ></a></li>
# 								-->
# <li><a href='javascript:go_returnUrl("2296","1803631");' title="새 창으로 열림"><img alt="soribada" src="/images/btn/btn_play_soribada.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("2407","1803631");' title="새 창으로 열림"><img alt="alleh music" src="/images/btn/btn_play_alleh.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("7829","1803631");' title="새 창으로 열림"><img alt="bainil" src="/images/btn/btn_play_bainil.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("5765","1803631");' title="새 창으로 열림"><img alt="vibe" src="/images/btn/btn_play_vibe.gif"/></a></li>
# <li><a href='javascript:go_returnUrl("8498","1803631");' title="새 창으로 열림"><img alt="vibe" src="/images/btn/btn_play_flo.gif"/></a></li>
# </ul>
# <span></span>
# </div>
# </div>
# </td>
# </tr>
# </table>

# %%
result = pd.DataFrame([[td.text for td in row.findAll('td')] for row in table.findChildren('tr')])
#print(table.findChildren(['tr']))
result.head()
# Out:
#       0     1     2                                                3  \
# 0  None  None  None                                             None
# 1     1     -             \n그대라는 시\n태연 (TAEYEON)|호텔 델루나 OST Part.3\n
# 2     2   new        \n내 맘을 볼 수 있나요\n헤이즈 (Heize)|호텔 델루나 OST Part.5\n
# 3     3     1                            \n술이 문제야\n장혜진, 윤민수|술이 문제야\n
# 4     4     -                                     \n니 소식\n송하예|니 소식\n
#
#                 4                                                 5  \
# 0            None                                              None
# 1  \n44,367,923\n                               \n냠냠엔터테인먼트\n카카오 M\n
# 2  \n36,229,004\n                               \n냠냠엔터테인먼트\n카카오 M\n
# 3  \n35,722,651\n  \n젤리피쉬 엔터테인먼트\n지니뮤직, Stone Music Entertainment\n
# 4  \n32,875,130\n                                 \n더하기미디어\n카카오 M\n
#
#                   6                                         7
# 0              None                                      None
# 1  트위터\n페이스북\n웨이브\n  \nPLAY\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n
# 2  트위터\n페이스북\n웨이브\n  \nPLAY\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n
# 3  트위터\n페이스북\n웨이브\n  \nPLAY\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n
# 4  트위터\n페이스북\n웨이브\n  \nPLAY\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n

# %%
pt = r'\W+'
col_names = [re.sub(pt, '', th.string) for th in table.find('tr')]
result = result.drop([1,2,4,6,7], axis=1)

# %%
col_names
# Out:
# ['', 'Ranking', 'TitleArtist', '가온지수', 'Production', 'Share', 'Play']

# %%
col_dict = dict(zip(result.columns, col_names[1:3]+[col_names[4]]))
result = result.rename(columns=col_dict)
result = result.drop(0)
result
# Out:
#     Ranking                                        TitleArtist  \
# 1         1         \n그대라는 시\n태연 (TAEYEON)|호텔 델루나 OST Part.3\n
# 2         2    \n내 맘을 볼 수 있나요\n헤이즈 (Heize)|호텔 델루나 OST Part.5\n
# 3         3                        \n술이 문제야\n장혜진, 윤민수|술이 문제야\n
# 4         4                                 \n니 소식\n송하예|니 소식\n
# 5         5                   \n헤어져줘서 고마워\n벤 (Ben)|헤어져줘서 고마워\n
# 6         6      \n2002\nAnne-Marie|Speak Your Mind (Deluxe)\n
# 7         7  \n오늘도 빛나는 너에게 (To You My Light) (Feat.이라...\n마...
# 8         8                                 \n포장마차\n황인욱|포장마차\n
# 9         9    \n사랑에 연습이 있었다면 (Prod. 2soo)\n임재현|사랑에 연습이 있었다면\n
# 10       10  \nSpeechless (Full)\nNaomi Scott|Aladdin (Orig...
# 184            \nInterscope Records\nUniversal Music\n
# 185  \nStone Music Entertainment, 화앤담픽쳐스\n지니뮤직, Sto...
# 186                                   \n쇼파르뮤직\n카카오 M\n
# 187                      \nYG Entertainment\nYG PLUS\n
# 188  \nStone Music Entertainment\nStone Music Enter...
# 189                                \n먼데이키즈 컴퍼니\n지니뮤직\n
# 190                      \nSM Entertainment\nDreamus\n
# 191  \nStone Music Entertainment\nStone Music Enter...
# 192               \nCapitol Records\nUniversal Music\n
# 193                        \n엠엘디엔터테인먼트, 카카오 M\n카카오 M\n
# 194            \nInterscope Records\nUniversal Music\n
# 195                     \nEpic Amsterdam\nSony Music\n
# 196            \nInterscope Records\nUniversal Music\n
# 197                                  \n미스틱스토리\n카카오 M\n
# 198                      \nYG Entertainment\nYG PLUS\n
# 199                                \n큐브엔터테인먼트\n카카오 M\n
# 200                     \nJYP Entertainment\nDreamus\n
#
# [200 rows x 3 columns]

# %%
# clean text within the table 
cleaned_result = result.apply(lambda x: x.apply(lambda y: re.sub(r'\n', ' ', y)))
alter = result['TitleArtist'].apply(lambda x: re.sub(r'\n', 'newline ', x))

cleaned_result['Album'] = result['TitleArtist'].apply(lambda x: re.search(r'\|(.*)$', x)[1])
cleaned_result['Artist'] = result['TitleArtist'].apply(lambda x: re.search(r'(.*)\|', x)[1])
cleaned_result['Title'] = alter.apply(lambda x: re.search(r'(?<=newline).*?(?=newline)', x)[0])
cleaned_result['Week'] = 31
cleaned_result['Year'] = 2019
cleaned_result.head()
# Out:
#   Ranking                                   TitleArtist  \
# 1       1        그대라는 시 태연 (TAEYEON)|호텔 델루나 OST Part.3
# 2       2   내 맘을 볼 수 있나요 헤이즈 (Heize)|호텔 델루나 OST Part.5
# 3       3                       술이 문제야 장혜진, 윤민수|술이 문제야
# 4       4                                니 소식 송하예|니 소식
# 5       5                  헤어져줘서 고마워 벤 (Ben)|헤어져줘서 고마워
#
#                                       Production              Album  \
# 1                                냠냠엔터테인먼트 카카오 M   호텔 델루나 OST Part.3
# 2                                냠냠엔터테인먼트 카카오 M   호텔 델루나 OST Part.5
# 3   젤리피쉬 엔터테인먼트 지니뮤직, Stone Music Entertainment              술이 문제야
# 4                                  더하기미디어 카카오 M                니 소식
# 5                                    메이저나인 지니뮤직           헤어져줘서 고마워
#
#          Artist          Title  Week  Year
# 1  태연 (TAEYEON)         그대라는 시    31  2019
# 2   헤이즈 (Heize)   내 맘을 볼 수 있나요    31  2019
# 3      장혜진, 윤민수         술이 문제야    31  2019
# 4           송하예           니 소식    31  2019
# 5       벤 (Ben)      헤어져줘서 고마워    31  2019

# %%
# @source a web scraping article I found on Towards Data Science
# https://towardsdatascience.com/a-short-practical-how-to-guide-to-scrape-data-from-a-website-using-python-888373227d4f

PATH = os.path.join("Users","catherinegee","Desktop","cs misc","ds-for-fun") # you need to change to your local path
res = pd.DataFrame()

end = '&targetTime=31&hitYear=2019&termGbn=week'
groups = ['&targetTime=', '&hitYear=', '&termGbn=week']

opts = soup.find(name='select', attrs={'id':'chart_week_select'})
lst = []
for c in opts.children:
    lst += [c]
    
num_times = len(lst) - 2
pth = '/Users/catherinegee/Desktop/cs misc/ds-for-fun/Kpop/data/table.csv'
cleaned_result.to_csv(pth)

# %%
def clean_df(result, table, week, year):
    """Cleans the table as done in example dataframe"""
    pt = r'\W+'
    col_names = [re.sub(pt, '', th.string) for th in table.find('tr')]
    if year <= 2017:
        result = result.drop([1,2,5,6], axis=1)
        col_dict = dict(zip(result.columns, col_names[1:4]))
    else:
        result = result.drop([1,2,4,6,7], axis=1)
        col_dict = dict(zip(result.columns, col_names[1:3]+[col_names[4]]))
    result = result.rename(columns=col_dict)
    result = result.drop(0)
    cleaned_result = result.apply(lambda x: x.apply(lambda y: re.sub(r'\n', ' ', y)))
    alter = result['TitleArtist'].apply(lambda x: re.sub(r'\n', 'newline ', x))

    cleaned_result['Album'] = result['TitleArtist'].apply(lambda x: re.search(r'\|(.*)$', x)[1])
    cleaned_result['Artist'] = result['TitleArtist'].apply(lambda x: re.search(r'(.*)\|', x)[1])
    cleaned_result['Title'] = alter.apply(lambda x: re.search(r'(?<=newline).*?(?=newline)', x)[0])
    cleaned_result['Week'] = week
    cleaned_result['Year'] = year
    return cleaned_result
    
def table_to_df(t, week, year): 
    """Turns the table into a datafram using pandas"""
    result = pd.DataFrame([[td.text for td in row.findAll('td')] for row in t.findChildren('tr')])
    return clean_df(result, t, week, year)

def update_date(week, year):
    """Updates the date by week number and year"""
    year = int(year)
    week = int(week) - 1
    if week == 0:
        year -= 1
        week = 52
    elif week < 10:
        week = '0' + str(week)
    #year = str(year)
    return int(week), year, groups[0] + str(week) + groups[1] + str(year) + groups[2]

# %%
for i in range(num_times):
    #print(i)
    week_n = re.search(r'(?<=&targetTime=).*?(?=&hitYear=)', end)[0] 
    year = re.search(r'(?<=&hitYear=).*?(?=&termGbn=week)', end)[0] 
    w, y, end = update_date(week_n, year)
    print(w,y,end)
    url_week = url + end
    pg = requests.get(url_week)
    sp = bs4.BeautifulSoup(pg.content, 'lxml')
    table = sp.find(name='table')
    df1 = table_to_df(table, w, y)
    res = res.append(df1)
    if i % 20 == 0:
        res.to_csv(pth)
# Out:
# 51 2009 &targetTime=51&hitYear=2009&termGbn=week
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-1ada7def7e72> in <module>()
#       9     sp = bs4.BeautifulSoup(pg.content, 'lxml')
#      10     table = sp.find(name='table')
# ---> 11     df1 = table_to_df(table, w, y)
#      12     #res = res.append(df1)
#      13     #if i % 100 == 0 or i == 1002:
#
# <ipython-input-11-19ace607dbd4> in table_to_df(t, week, year)
#      23 def table_to_df(t, week, year):
#      24     """Turns the table into a datafram using pandas"""
# ---> 25     result = pd.DataFrame([[td.text for td in row.findAll('td')] for row in t.findChildren('tr')])
#      26     return clean_df(result, t, week, year)
#      27
#
# AttributeError: 'NoneType' object has no attribute 'findChildren'

# %%
test = url + '&targetTime=52&hitYear=2017&termGbn=week'
pg = requests.get(test)
sp = bs4.BeautifulSoup(pg.content, 'lxml')
table = sp.find(name='table')
table

# %%
result = pd.DataFrame([[td.text for td in row.findAll('td')] for row in table.findChildren('tr')])
result.head()

# %%
col_names = [re.sub(pt, '', th.string) for th in table.find('tr')]
col_names
